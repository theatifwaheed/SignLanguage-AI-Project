# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('1depth.avi')

while True:
    _, frame = cap.read()

    #cv.imshow('frame', frame)
    imgray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    imgray = imgray.astype(np.uint8)
    print ((imgray).max(), (imgray).min())
    th = cv.inRange(imgray, 60, 80)
    #_, th = cv.threshold(imgray, 1, 255, cv.THRESH_BINARY)
    countours, heirarchy = cv.findContours(th, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    MaxC = max(countours, key=cv.contourArea)
    for countour in countours:
        hull = cv.convexHull(MaxC)
    final = cv.drawContours(frame, [hull], -1, (0, 0, 255), 2)
    print("countours: " + str(len(MaxC)))
    cv.imshow('threshold', th)
    cv.imshow('Hull', final)
    if cv.waitKey(30) & 0xFF == ord('q'):
        break
cap.release()
cv.destroyAllWindows()
# Out:
# 125 0
# countours: 188
# 125 0
# countours: 169
# 125 0
# countours: 199
# 129 0
# countours: 172
# 130 0
# countours: 190
# 126 0
# countours: 179
# 127 0
# countours: 157
# 124 0
# countours: 219
# 124 0
# countours: 161
# 124 0
# countours: 170
# 128 0
# countours: 180
# 125 0
# countours: 166
# 124 0
# countours: 141
# 124 0
# countours: 177
# 125 0
# countours: 183
# 128 0
# countours: 209
# 127 0
# countours: 169
# 127 0
# countours: 215
# 125 0
# countours: 179
# 128 0
# countours: 169
# 125 0
# countours: 154
# 125 0
# countours: 154
# 125 0
# countours: 155
# 125 0
# countours: 143
# 125 0
# countours: 142
# 125 0
# countours: 168
# 123 0
# countours: 178
# 123 0
# countours: 173
# 125 0
# countours: 181
# 127 0
# countours: 199
# 123 0
# countours: 150
# 126 0
# countours: 174
# 124 0
# countours: 119
# 125 0
# countours: 169
# 125 0
# countours: 175
# 124 0
# countours: 143
# 124 0
# countours: 145
# 125 0
# countours: 196
# 125 0
# countours: 252
# 124 0
# countours: 241
# 125 0
# countours: 201
# 127 0
# countours: 224
# 124 0
# countours: 227
# 124 0
# countours: 240
# 125 0
# countours: 198
# 125 0
# countours: 212
# 125 0
# countours: 222
# 133 0
# countours: 210
# 123 0
# countours: 196
# 128 0
# countours: 179
# 125 0
# countours: 183
# 124 0
# countours: 202
# 126 0
# countours: 189
# 124 0
# countours: 213
# 125 0
# countours: 243
# 126 0
# countours: 192
# 129 0
# countours: 215
# 126 0
# countours: 216
# 129 0
# countours: 216
# 123 0
# countours: 172
# 124 0
# countours: 182
# 126 0
# countours: 165
# 126 0
# countours: 199
# 126 0
# countours: 179
# 125 0
# countours: 195
# 125 0
# countours: 198
# 124 0
# countours: 166
# 124 0
# countours: 198
# 124 0
# countours: 207
# 129 0
# countours: 216
# 126 0
# countours: 209
# 125 0
# countours: 169
# 125 0
# countours: 199
# 125 0
# countours: 184
# 125 0
# countours: 203
# 123 0
# countours: 199
# 125 0
# countours: 222
# 124 0
# countours: 220
# 125 0
# countours: 219
# 127 0
# countours: 221
# 124 0
# countours: 206
# 124 0
# countours: 212
# 124 0
# countours: 178
# 126 0
# countours: 209
# 124 0
# countours: 198
# 125 0
# countours: 237
# 127 0
# countours: 195
# 125 0
# countours: 196
# 124 0
# countours: 169
# 125 0
# countours: 228
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-ff79e00742b5> in <module>
#       8
#       9     #cv.imshow('frame', frame)
# ---> 10     imgray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
#      11     imgray = imgray.astype(np.uint8)
#      12     print ((imgray).max(), (imgray).min())
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
